# %%
professor = "choi"

# %%
professor
# Out:
# 'choi'

# %%
print(professor)
# Out:
# choi

# %%
a=7
a
# Out:
# 7

# %%
b=5
as
b
# Out:
# 5

# %%
a=1
a
# Out:
# 1

# %%
type(a)
# Out:
# int

# %%
a = 1.1
a
# Out:
# 1.1

# %%
type(a)
# Out:
# float

# %%
a = '한글'
a
# Out:
# '한글'

# %%
type(a)
# Out:
# str

# %%
a = True
a
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
up7=8
up7
# Out:
# 8

# %%
25+30
# Out:
# 55

# %%
print(7//2)
# Out:
# 3

# %%
한글 = 'ㅁㅁㅁ'
한글
# Out:
# 'ㅁㅁㅁ'

# %%
text = "kim's "
text
# Out:
# "kim's "

# %%
print(7%2)
# Out:
# 1

# %%
print(a,b,text,sep=',',end=' ')
print('줄바꿈')
# Out:
# True,5,kim's  줄바꿈

# %%
a = input('숫자를 입력하세요 >>>')
# Out:
# 숫자를 입력하세요 >>> 9

# %%
a= int(a)
a
# Out:
# 9

# %%
type(a)
# Out:
# int

# %%
#과일을 상자에 담으려고합니다
#한상자에 들어가는 과일의 갯수와, 총 과일의 수를 입력받아서
#몇박스 몇개가 나오는지 출력하세요

# %%
box = int(input('box에 들어가는 과일의 수>>>'))
total = int(input('총 과일 수 >>>'))
print(total//box,'박스',total%box,'개')
# Out:
# box에 들어가는 과일의 수>>> 6
# 총 과일 수 >>> 50
# 8 박스 2 개

# %%
colors = ['red', 'blue', 'green', 1, 1.2, [1,2,3]]

# %%
type(colors)
# Out:
# list

# %%
colors[2]
# Out:
# 'green'

# %%
type(colors[2])
# Out:
# str

# %%
colors[5]
# Out:
# [1, 2, 3]

# %%
colors[5][1]
# Out:
# 2

# %%
colors[1:3]
# Out:
# ['blue', 'green']

# %%
colors = ['red', 'blue', 'green', 1, 1.2, [1,2,3]]
cities = ['서울', '부산', '광주']

# %%
colors + cities
# Out:
# ['red', 'blue', 'green', 1, 1.2, [1, 2, 3], '서울', '부산', '광주']

# %%
print("Hello World")
# Out:
# Hello World

# %%
a=1
a=a+1
print(a)
# Out:
# 2

# %%
a+=1
print(a)
# Out:
# 3

# %%
a=a-1
a-=1
print(a)
# Out:
# 1

# %%
color = ['red', 'blue', 'green']
print(color[0])
print(color[1])
print(len(color))
# Out:
# red
# blue
# 3

# %%
color
# Out:
# ['red', 'blue', 'green']

# %%
color
