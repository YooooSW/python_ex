# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([ -87,  -61,  -13,  -94,  -80, -150, -158, -186, -218, -163, -247,
#        -310, -382, -363, -343, -325, -384, -477, -457, -500, -421, -367,
#        -332, -320, -229, -214, -240, -148, -221, -226, -233, -166, -117,
#         -63,  -85,  -37,   45,  141,   55,   36,   93,  102,   41,   -4,
#          57,    6,   36,   78,   72,   14], dtype=int32)

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 1. 폰트 파일로 FontProperties()생성 후 사용

import matplotlib.font_manager as fm

path = '나눔손글씨 가람연꽃.ttf'
fontprop = fm.FontProperties(fname=path,size=15)

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식 가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 2. matplotlib.rcParams[]로 설정
import matplotlib

print('설정 파일 위치 : ', matplotlib.matplotlib_fname())
print('기본 설정 폰트 : ', plt.rcParams['font.family'])
print('기본 설정 사이즈 : ', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 :  C:\Users\admin\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 :  ['sans-serif']
# 기본 설정 사이즈 :  10.0

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
fm.findSystemFonts()[:4]
# Out:
# ['C:\\Windows\\Fonts\\WINGDNG2.TTF',
#  'C:\\windows\\Fonts\\gulim.ttc',
#  'C:\\windows\\Fonts\\PAPYRUS.TTF',
#  'C:\\windows\\Fonts\\framd.ttf']

# %%
import os
os.listdir("C:/")
# Out:
# ['$MfeDeepRem',
#  '$Recycle.Bin',
#  '$WINDOWS.~BT',
#  '$Windows.~WS',
#  '$WinREAgent',
#  'app',
#  'Documents and Settings',
#  'DumpStack.log.tmp',
#  'ESD',
#  'gitwd',
#  'hiberfil.sys',
#  'hp',
#  'msdia80.dll',
#  'MSOCache',
#  'oraclexe',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'swapfile.sys',
#  'System Volume Information',
#  'System.sav',
#  'test',
#  'test01',
#  'testgit',
#  'Users',
#  'Windows',
#  'yoo']

# %%
[(f.name, f.name) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumMyeongjo YetHangul', 'NanumMyeongjo YetHangul'),
#  ('NanumBarunGothic YetHangul', 'NanumBarunGothic YetHangul'),
#  ('NanumBarunGothic', 'NanumBarunGothic'),
#  ('NanumGothic', 'NanumGothic'),
#  ('NanumGothic', 'NanumGothic'),
#  ('NanumGothic', 'NanumGothic'),
#  ('Nanum Pen Script OTF', 'Nanum Pen Script OTF'),
#  ('NanumBarunGothicOTF YetHangul', 'NanumBarunGothicOTF YetHangul'),
#  ('Nanum GaRamYeonGgoc', 'Nanum GaRamYeonGgoc'),
#  ('Nanum Brush Script OTF', 'Nanum Brush Script OTF'),
#  ('Nanum Pen Script', 'Nanum Pen Script'),
#  ('NanumMyeongjoOTF YetHangul', 'NanumMyeongjoOTF YetHangul'),
#  ('NanumGothic', 'NanumGothic')]

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 3. 설정파일 수정
import matplotlib
import matplotlib.pyplot as plt

print('설정 파일 위치 : ', matplotlib.matplotlib_fname())
print('기본 설정 폰트 : ', plt.rcParams['font.family'])
print('기본 설정 사이즈 : ', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 :  C:\Users\admin\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 :  ['Malgun Gothic']
# 기본 설정 사이즈 :  13.0
