# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([ -88, -114, -178, -187, -129, -139, -133,  -98, -157, -202, -117,
#         -77,  -65, -127,  -43, -133,  -59,  -85,  -30,   17,   90,    3,
#         -74,    9,   39,   77,   57,   93,   70,  158,  243,  340,  351,
#         257,  234,  232,  144,  105,   89,   -8,  -41,   36,   54,   91,
#          -7,   43,  -19,   70,   79,   89])

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.

# %%
# 1. 폰트 파일로 FontProperties()생성 후 사용

import matplotlib.font_manager as fm

path = '나눔손글씨 가람연꽃.ttf'
fontprop = fm.FontProperties(fname=path,size=15)

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식 가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(분)')
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.

# %%
# 2. matplotlib.rcParams[]로 설정
import matplotlib

print('설정 파일 위치 : ', matplotlib.matplotlib_fname())
print('기본 설정 폰트 : ', plt.rcParams['font.family'])
print('기본 설정 사이즈 : ', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 :  c:\Users\admin\AppData\Local\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 :  ['NanumSquare Neo Light']
# 기본 설정 사이즈 :  13.0

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
fm.findSystemFonts()[:4]
# Out:
# ['C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\NotoSans-CondensedBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\NachlieliCLM-LightOblique.otf']

# %%
[(f.name,f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# []

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 3. 설정파일 수정
import matplotlib
import matplotlib.pyplot as plt

print('설정 파일 위치 : ', matplotlib.matplotlib_fname())
print('기본 설정 폰트 : ', plt.rcParams['font.family'])
print('기본 설정 사이즈 : ', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 :  c:\Users\admin\AppData\Local\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 :  ['NanumSquare Neo Light']
# 기본 설정 사이즈 :  13.0
